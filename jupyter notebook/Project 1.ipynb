# %%
import pandas as pd

# %%
df=pd.read_csv('US_Accidents_March23.csv')
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# 2        2016-02-08 07:19:27  39.063148  -84.032608       NaN        NaN
# 3        2016-02-08 07:53:34  39.747753  -84.205582       NaN        NaN
# 4        2016-02-08 08:09:07  39.627781  -84.188354       NaN        NaN
# ...                      ...        ...         ...       ...        ...
# 7728389  2019-08-23 18:32:01  34.002480 -117.379360  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23  32.766960 -117.148060  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49  33.775450 -117.847790  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42  33.992460 -118.403020  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31  34.133930 -117.230920  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 0               0.010  ...      False   False  False           False
# 1               0.010  ...      False   False  False           False
# 2               0.010  ...      False   False  False           False
# 3               0.010  ...      False   False  False           False
# 4               0.010  ...      False   False  False           False
# ...               ...  ...        ...     ...    ...             ...
# 7728389         0.543  ...      False   False  False           False
# 7728390         0.338  ...      False   False  False           False
# 7728391         0.561  ...      False   False  False           False
# 7728392         0.772  ...      False   False  False           False
# 7728393         0.537  ...      False   False  False           False
#
#         Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0                False        False          Night          Night
# 1                False        False          Night          Night
# 2                 True        False          Night          Night
# 3                False        False          Night            Day
# 4                 True        False            Day            Day
# ...                ...          ...            ...            ...
# 7728389          False        False            Day            Day
# 7728390          False        False            Day            Day
# 7728391          False        False            Day            Day
# 7728392          False        False            Day            Day
# 7728393          False        False            Day            Day
#
#         Nautical_Twilight Astronomical_Twilight
# 0                   Night                 Night
# 1                   Night                   Day
# 2                     Day                   Day
# 3                     Day                   Day
# 4                     Day                   Day
# ...                   ...                   ...
# 7728389               Day                   Day
# 7728390               Day                   Day
# 7728391               Day                   Day
# 7728392               Day                   Day
# 7728393               Day                   Day
#
# [7728394 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# min    0.000000e+00   -8.900000e+01  -8.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.900000e+01   4.300000e+01  4.800000e+01
# 50%    3.000000e-02    6.400000e+01   6.200000e+01  6.700000e+01
# 75%    4.640000e-01    7.600000e+01   7.500000e+01  8.400000e+01
# max    4.417500e+02    2.070000e+02   2.070000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  7.587715e+06    7.551296e+06     7.157161e+06       5.524808e+06
# mean   2.953899e+01    9.090376e+00     7.685490e+00       8.407210e-03
# std    1.006190e+00    2.688316e+00     5.424983e+00       1.102246e-01
# min    0.000000e+00    0.000000e+00     0.000000e+00       0.000000e+00
# 25%    2.937000e+01    1.000000e+01     4.600000e+00       0.000000e+00
# 50%    2.986000e+01    1.000000e+01     7.000000e+00       0.000000e+00
# 75%    3.003000e+01    1.000000e+01     1.040000e+01       0.000000e+00
# max    5.863000e+01    1.400000e+02     1.087000e+03       3.647000e+01

# %%
numerics=['int16','int32','int64','float16','float32','float64']
numeric_df=df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 13

# %%
missing_percentages=df.isna().sum().sort_values(ascending=False)/len(df)
missing_percentages
# Out:
# End_Lng                  4.402935e-01
# End_Lat                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Sunrise_Sunset           3.007869e-03
# Civil_Twilight           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Nautical_Twilight        3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# ID                       0.000000e+00
# Distance(mi)             0.000000e+00
# Start_Lng                0.000000e+00
# Source                   0.000000e+00
# Severity                 0.000000e+00
# Start_Time               0.000000e+00
# End_Time                 0.000000e+00
# Start_Lat                0.000000e+00
# County                   0.000000e+00
# Amenity                  0.000000e+00
# Country                  0.000000e+00
# State                    0.000000e+00
# Bump                     0.000000e+00
# Crossing                 0.000000e+00
# Give_Way                 0.000000e+00
# Junction                 0.000000e+00
# Station                  0.000000e+00
# Roundabout               0.000000e+00
# Railway                  0.000000e+00
# No_Exit                  0.000000e+00
# Turning_Loop             0.000000e+00
# Traffic_Signal           0.000000e+00
# Traffic_Calming          0.000000e+00
# Stop                     0.000000e+00
# dtype: float64

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages!=0].plot(kind='barh')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object

# %%
cities=df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accident=df.City.value_counts()
cities_by_accident
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
#                   ...
# Rapid River           1
# Cat Spring            1
# Glenwood City         1
# Downing               1
# Marfa                 1
# Name: count, Length: 13678, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
type(cities_by_accident)
# Out:
# pandas.core.series.Series

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.histplot(cities_by_accident,log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
cities_by_accident[cities_by_accident==1]
# Out:
# City
# American Fork-Pleasant Grove    1
# Waldoboro                       1
# Kinsley                         1
# Killona                         1
# Jeanerette                      1
#                                ..
# Rapid River                     1
# Cat Spring                      1
# Glenwood City                   1
# Downing                         1
# Marfa                           1
# Name: count, Length: 1023, dtype: int64

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='%Y-%m-%d %H:%M:%S.%f', errors='coerce')

# %%
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\Users\nivet\AppData\Local\Temp\ipykernel_7232\3320439031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# C:\Users\nivet\AppData\Local\Temp\ipykernel_7232\4238415869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
sundays_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sundays_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\Users\nivet\AppData\Local\Temp\ipykernel_7232\1612182456.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sundays_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
monday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(monday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\Users\nivet\AppData\Local\Temp\ipykernel_7232\1709319197.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(monday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
df_2019=df[df.Start_Time.dt.year==2019]
df_2019_Bing=df_2019[df_2019.Source=='MapQuest']
sns.histplot(df_2019_Bing['Start_Time'].dt.month, bins=12, kde=False)
# Out:
# <Axes: >

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sample_df=df.sample(int(0.1*len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng,y=sample_df.Start_Lat,size=0.001)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from folium) (2.0.0)
# Requirement already satisfied: requests in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2024.6.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nivet\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (2024.6.2)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/108.4 kB ? eta -:--:--
#    ----------- --------------------------- 30.7/108.4 kB 262.6 kB/s eta 0:00:01
#    -------------- ------------------------ 41.0/108.4 kB 281.8 kB/s eta 0:00:01
#    ----------------------------- --------- 81.9/108.4 kB 459.5 kB/s eta 0:00:01
#    --------------------------------- ----- 92.2/108.4 kB 350.1 kB/s eta 0:00:01
#    -------------------------------------- 108.4/108.4 kB 392.7 kB/s eta 0:00:00
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Downloading xyzservices-2024.6.0-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.9 kB ? eta -:--:--
#    ------------------- -------------------- 41.0/83.9 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 83.9/83.9 kB 944.7 kB/s eta 0:00:00
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.2 folium-0.17.0 xyzservices-2024.6.0

# %%
import folium

# %%
lat,lon=df.Start_Lat[0],df.Start_Lng[0]
lat,lon
# Out:
# (np.float64(39.865147), np.float64(-84.058723))

# %%
sampled_df = df[['Start_Lat', 'Start_Lng']].sample(100)
for index, row in sampled_df.iterrows():
    print(row)
# Out:
# Start_Lat    40.682850
# Start_Lng   -73.669764
# Name: 5269452, dtype: float64
# Start_Lat    34.548492
# Start_Lng   -82.131185
# Name: 6771201, dtype: float64
# Start_Lat    40.778751
# Start_Lng   -74.428619
# Name: 1988558, dtype: float64
# Start_Lat    35.46424
# Start_Lng   -97.63649
# Name: 7045629, dtype: float64
# Start_Lat    34.546581
# Start_Lng   -82.807083
# Name: 1762808, dtype: float64
# Start_Lat     33.98237
# Start_Lng   -118.28041
# Name: 7164132, dtype: float64
# Start_Lat     45.515087
# Start_Lng   -122.659744
# Name: 3230112, dtype: float64
# Start_Lat     34.154301
# Start_Lng   -118.377098
# Name: 1806237, dtype: float64
# Start_Lat    38.115128
# Start_Lng   -85.701866
# Name: 3294326, dtype: float64
# Start_Lat     34.162930
# Start_Lng   -118.158569
# Name: 76291, dtype: float64
# Start_Lat    44.154362
# Start_Lng   -92.199364
# Name: 770219, dtype: float64
# Start_Lat    36.785213
# Start_Lng   -76.160339
# Name: 2116643, dtype: float64
# Start_Lat     38.657633
# Start_Lng   -120.936380
# Name: 6135636, dtype: float64
# Start_Lat    40.44949
# Start_Lng   -80.10743
# Name: 1897755, dtype: float64
# Start_Lat    32.655830
# Start_Lng   -96.746552
# Name: 607281, dtype: float64
# Start_Lat     33.670403
# Start_Lng   -117.883419
# Name: 5743996, dtype: float64
# Start_Lat    32.667048
# Start_Lng   -97.350486
# Name: 6148728, dtype: float64
# Start_Lat     38.851690
# Start_Lng   -110.881088
# Name: 7387220, dtype: float64
# Start_Lat     37.156729
# Start_Lng   -121.655979
# Name: 7390894, dtype: float64
# Start_Lat     34.35975
# Start_Lng   -117.43536
# Name: 3529296, dtype: float64
# Start_Lat    28.504061
# Start_Lng   -81.244980
# Name: 4277016, dtype: float64
# Start_Lat     45.52470
# Start_Lng   -122.68666
# Name: 7482172, dtype: float64
# Start_Lat    41.685829
# Start_Lng   -88.066406
# Name: 4780105, dtype: float64
# Start_Lat     39.625183
# Start_Lng   -121.953616
# Name: 4926225, dtype: float64
# Start_Lat     41.093250
# Start_Lng   -123.700729
# Name: 941575, dtype: float64
# Start_Lat    37.186503
# Start_Lng   -93.317736
# Name: 5484338, dtype: float64
# Start_Lat    30.473125
# Start_Lng   -97.798310
# Name: 3662192, dtype: float64
# Start_Lat     33.960152
# Start_Lng   -118.254028
# Name: 1559756, dtype: float64
# Start_Lat    38.253559
# Start_Lng   -85.720604
# Name: 3062087, dtype: float64
# Start_Lat    35.241402
# Start_Lng   -80.997437
# Name: 2084707, dtype: float64
# Start_Lat    36.022488
# Start_Lng   -83.478378
# Name: 2193752, dtype: float64
# Start_Lat    38.547069
# Start_Lng   -90.425780
# Name: 4739093, dtype: float64
# Start_Lat    29.814358
# Start_Lng   -95.429382
# Name: 2362867, dtype: float64
# Start_Lat    35.260830
# Start_Lng   -80.894638
# Name: 1386731, dtype: float64
# Start_Lat    35.535138
# Start_Lng   -93.428341
# Name: 4153508, dtype: float64
# Start_Lat     37.76467
# Start_Lng   -121.41066
# Name: 6945525, dtype: float64
# Start_Lat    45.288795
# Start_Lng   -93.003105
# Name: 2740506, dtype: float64
# Start_Lat    35.321396
# Start_Lng   -80.734062
# Name: 751073, dtype: float64
# Start_Lat    33.870552
# Start_Lng   -98.535889
# Name: 2067815, dtype: float64
# Start_Lat    38.653944
# Start_Lng   -87.129711
# Name: 4018622, dtype: float64
# Start_Lat     37.523512
# Start_Lng   -122.266836
# Name: 7015799, dtype: float64
# Start_Lat    30.252475
# Start_Lng   -90.403479
# Name: 3871582, dtype: float64
# Start_Lat    35.606911
# Start_Lng   -82.480347
# Name: 1185470, dtype: float64
# Start_Lat     34.12536
# Start_Lng   -118.47654
# Name: 7314701, dtype: float64
# Start_Lat    36.061186
# Start_Lng   -79.391508
# Name: 4963669, dtype: float64
# Start_Lat     33.82595
# Start_Lng   -118.21260
# Name: 7584435, dtype: float64
# Start_Lat     35.335789
# Start_Lng   -119.016472
# Name: 2847072, dtype: float64
# Start_Lat     41.783286
# Start_Lng   -124.201979
# Name: 5054219, dtype: float64
# Start_Lat    33.855091
# Start_Lng   -87.337616
# Name: 513810, dtype: float64
# Start_Lat    44.98853
# Start_Lng   -93.34956
# Name: 3425588, dtype: float64
# Start_Lat     32.74952
# Start_Lng   -117.12305
# Name: 7628844, dtype: float64
# Start_Lat    34.142336
# Start_Lng   -82.148570
# Name: 6542650, dtype: float64
# Start_Lat    38.771436
# Start_Lng   -90.292437
# Name: 4623377, dtype: float64
# Start_Lat    35.836501
# Start_Lng   -80.338357
# Name: 4324127, dtype: float64
# Start_Lat    29.732599
# Start_Lng   -95.441490
# Name: 508355, dtype: float64
# Start_Lat    35.530048
# Start_Lng   -97.574562
# Name: 3113583, dtype: float64
# Start_Lat    40.899540
# Start_Lng   -74.234703
# Name: 2047442, dtype: float64
# Start_Lat     37.945656
# Start_Lng   -122.520271
# Name: 1501400, dtype: float64
# Start_Lat    40.618492
# Start_Lng   -75.501160
# Name: 383103, dtype: float64
# Start_Lat     32.707386
# Start_Lng   -117.147720
# Name: 46978, dtype: float64
# Start_Lat    39.951475
# Start_Lng   -75.163869
# Name: 5417179, dtype: float64
# Start_Lat    29.595509
# Start_Lng   -95.467049
# Name: 2489239, dtype: float64
# Start_Lat     33.457166
# Start_Lng   -112.340923
# Name: 6294611, dtype: float64
# Start_Lat    29.721291
# Start_Lng   -95.441277
# Name: 2652647, dtype: float64
# Start_Lat    38.867453
# Start_Lng   -77.002314
# Name: 4409441, dtype: float64
# Start_Lat    34.920521
# Start_Lng   -81.993538
# Name: 1452814, dtype: float64
# Start_Lat     33.965836
# Start_Lng   -118.370496
# Name: 7265636, dtype: float64
# Start_Lat    36.150842
# Start_Lng   -86.855040
# Name: 6240471, dtype: float64
# Start_Lat     38.558128
# Start_Lng   -121.473961
# Name: 6183, dtype: float64
# Start_Lat    35.138859
# Start_Lng   -80.738884
# Name: 2851538, dtype: float64
# Start_Lat    35.127429
# Start_Lng   -81.139799
# Name: 4529348, dtype: float64
# Start_Lat    39.224644
# Start_Lng   -84.366508
# Name: 940199, dtype: float64
# Start_Lat    33.524239
# Start_Lng   -81.620369
# Name: 3027499, dtype: float64
# Start_Lat    35.845432
# Start_Lng   -78.680284
# Name: 6886234, dtype: float64
# Start_Lat    33.395645
# Start_Lng   -81.987236
# Name: 2690759, dtype: float64
# Start_Lat    25.854061
# Start_Lng   -80.322472
# Name: 1779607, dtype: float64
# Start_Lat     32.785603
# Start_Lng   -117.145325
# Name: 318210, dtype: float64
# Start_Lat    29.731858
# Start_Lng   -95.266369
# Name: 7644174, dtype: float64
# Start_Lat    42.49198
# Start_Lng   -83.02223
# Name: 3494407, dtype: float64
# Start_Lat     31.76841
# Start_Lng   -106.26091
# Name: 1118034, dtype: float64
# Start_Lat    33.112629
# Start_Lng   -79.793388
# Name: 1259668, dtype: float64
# Start_Lat    40.698273
# Start_Lng   -73.518197
# Name: 4212493, dtype: float64
# Start_Lat    34.928223
# Start_Lng   -92.081108
# Name: 659159, dtype: float64
# Start_Lat    40.039326
# Start_Lng   -75.007373
# Name: 6778682, dtype: float64
# Start_Lat    42.295793
# Start_Lng   -87.888797
# Name: 3908640, dtype: float64
# Start_Lat    38.280537
# Start_Lng   -85.688461
# Name: 837620, dtype: float64
# Start_Lat     34.155647
# Start_Lng   -118.445781
# Name: 4013755, dtype: float64
# Start_Lat    38.821595
# Start_Lng   -91.142138
# Name: 6629815, dtype: float64
# Start_Lat    29.690260
# Start_Lng   -95.551193
# Name: 2541969, dtype: float64
# Start_Lat    35.241512
# Start_Lng   -80.849837
# Name: 5419185, dtype: float64
# Start_Lat     34.379281
# Start_Lng   -117.418120
# Name: 3954682, dtype: float64
# Start_Lat     47.644257
# Start_Lng   -122.304405
# Name: 335747, dtype: float64
# Start_Lat    42.253892
# Start_Lng   -83.440508
# Name: 4775523, dtype: float64
# Start_Lat     46.145154
# Start_Lng   -115.978456
# Name: 7644199, dtype: float64
# Start_Lat    38.191368
# Start_Lng   -85.728783
# Name: 639288, dtype: float64
# Start_Lat     34.031849
# Start_Lng   -117.758148
# Name: 705296, dtype: float64
# Start_Lat    39.93409
# Start_Lng   -74.94965
# Name: 7330808, dtype: float64
# Start_Lat    34.037189
# Start_Lng   -81.090927
# Name: 2385412, dtype: float64
# Start_Lat    37.45918
# Start_Lng   -77.09743
# Name: 7124427, dtype: float64
# Start_Lat     47.551086
# Start_Lng   -122.260338
# Name: 310605, dtype: float64

# %%
zip(list(df.Start_Lat),list(df.Start_Lng))

# %%
from folium.plugins import HeatMap

# %%
sample_df=df.sample(int(0.001*len(df)))
lat_lon_pairs=list(zip(list(sample_df.Start_Lat),list(sample_df.Start_Lng)))

# %%
map=folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4ef7f0f27ddd1e55a590e76f3394f6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4ef7f0f27ddd1e55a590e76f3394f6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4ef7f0f27ddd1e55a590e76f3394f6f = L.map(
#                 &quot;map_e4ef7f0f27ddd1e55a590e76f3394f6f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fb8d3977b7b0262b4b42b29afd11a9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0fb8d3977b7b0262b4b42b29afd11a9c.addTo(map_e4ef7f0f27ddd1e55a590e76f3394f6f);
#
#
#             var heat_map_3b8293723231baf2e176d85125c1a5f4 = L.heatLayer(
#                 [[34.152399, -118.09867], [40.098657, -76.10119499999998], [42.799313, -123.254513], [40.609502, -111.939782], [41.879841, -93.571365], [33.956787, -80.556301], [30.258911, -82.12297099999998], [34.013882, -86.555412], [43.109467, -77.463264], [41.830322, -88.036079], [33.344303000000004, -111.867409], [33.441649, -111.658366], [42.53755200000001, -71.743935], [35.505225, -78.60755400000002], [28.451483000000003, -81.23509200000002], [33.084877, -80.652367], [29.919849, -81.41233100000002], [38.74353, -90.605209], [37.686675, -122.124912], [40.36195900000001, -121.511734], [37.83839, -122.295082], [40.696168, -111.93893], [40.95456400000001, -111.89107], [37.46244, -77.853219], [32.813257, -96.804114], [35.659359, -119.508754], [40.69353, -111.90258], [35.202499, -80.725975], [36.323463, -86.704666], [38.89785, -121.07466399999998], [37.00655579549309, -113.00737738555428], [42.003567, -88.00383000000002], [40.91, -74.176559], [32.69532, -97.254962], [34.005101, -118.171677], [28.583223, -81.22416], [47.080653905644034, -120.73158144893296], [40.425062, -75.241791], [42.783407, -78.77250500000002], [42.15976, -72.363893], [33.878986, -81.095282], [32.83899, -117.14651], [35.011105, -81.91259000000002], [37.688204, -122.073609], [36.761287, -119.831998], [34.271763, -118.350471], [39.387351, -80.20819399999998], [39.954765, -82.986221], [39.774413, -84.142865], [41.89607, -112.55173], [40.569164, -78.323111], [46.281792, -92.661186], [47.010895, -123.370767], [34.266034000000005, -118.465679], [39.811077, -86.045715], [25.730978250380844, -80.38435578307922], [40.613297, -75.47758499999998], [34.077676000000004, -117.691622], [35.503858, -80.8665], [33.921246000000004, -84.35762], [37.07988, -109.548027], [41.859341, -88.04164899999998], [38.63942700000001, -121.383432], [42.20223, -121.706961], [26.612198, -81.803078], [43.048173, -76.14272], [27.32600900000001, -82.514114], [40.70719, -74.33816], [40.968651, -73.817299], [35.067162, -106.564392], [30.350782, -91.08327], [27.410885, -82.505424], [33.93018, -118.36998], [33.496449, -112.112633], [39.12439000000001, -121.078018], [36.210705, -119.47508700000002], [38.190613, -85.729439], [35.052608, -80.774526], [29.79973, -95.41008], [34.227508, -117.253335], [29.630461, -95.170364], [34.02078, -117.8147], [38.854251, -76.98007], [32.29739, -110.9952], [34.117048, -117.861328], [34.219248, -117.071678], [43.80310177782152, -84.67640519101774], [34.09322619421915, -80.86071610412186], [29.715527, -95.571426], [28.45147, -81.09999], [41.595909000000006, -93.625252], [37.410244, -121.911331], [37.084332, -122.268211], [36.829037, -76.309937], [35.901141, -78.65395699999998], [40.07822, -74.15596], [40.85741, -111.90559], [42.1146, -122.621302], [38.82399, -77.30751], [40.173166, -75.09765300000002], [33.756893, -78.96459300000002], [35.536181, -90.125002], [37.882015, -121.777336], [41.67915, -83.51578], [40.134331, -75.44953000000002], [33.412696000000004, -86.967333], [30.219786, -97.837624], [41.297745, -95.963806], [37.314026, -121.827072], [39.78862, -75.69565], [40.78238, -111.91685], [28.449837, -81.473338], [38.219311, -90.409668], [44.888355, -93.362378], [35.63115399999999, -78.861108], [33.941839, -118.300263], [34.064529, -118.010979], [33.892421, -84.258053], [37.935482, -122.51683], [40.137052, -111.949598], [26.705763, -80.075211], [45.2009, -123.142543], [33.476139, -117.138916], [37.09276, -80.57276], [47.624546, -122.335848], [40.028141, -75.024026], [45.054218, -92.805122], [25.928828, -80.184263], [41.749851, -88.06397199999998], [25.450166, -80.477188], [37.312456, -120.518249], [28.551912, -81.491336], [29.813248, -95.372643], [33.979889, -81.275131], [37.652012, -77.451363], [38.394669, -122.864128], [47.777637, -122.329956], [34.44186, -86.942009], [41.577859, -72.14000899999998], [38.966143, -77.02759499999998], [26.071017, -80.166667], [41.794476, -87.631599], [32.939941, -96.7
